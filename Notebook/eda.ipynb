# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("Data/raw/SKAB")
csv_files = list(DATA_DIR.rglob("*.csv"))
print(f"Total CSV files found: {len(csv_files)}")

all_dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    
    # Optional: keep file name
    df["source_file"] = file.name
    
    all_dfs.append(df)

# Combine into one dataframe
Master_df = pd.concat(all_dfs, ignore_index=True)

# Preview
print(Master_df.shape)
Master_df.head()
# Out:
# Total CSV files found: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 19
#      15
#      16     all_dfs.append(df)
#      17
#      18 # Combine into one dataframe
# ---> 19 Master_df = pd.concat(all_dfs, ignore_index=True)
#      20
#      21 # Preview
#      22 print(Master_df.shape)
#
# File c:\Users\ramrahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File c:\Users\ramrahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate
